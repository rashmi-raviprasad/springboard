# %%
import os
import time
import pytz
import pandas as pd
from tqdm import tqdm
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir('/content')
from google.colab import files
keys = files.upload()
# Out:
#      <input type="file" id="files-b62d981b-a74e-475e-b402-11f8f6122a44" name="files[]" multiple disabled />
#      <output id="result-b62d981b-a74e-475e-b402-11f8f6122a44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ssh.tar.gz to ssh.tar.gz

# %%
# !rm -rf /root/.ssh
# !mkdir /root/.ssh

# !tar xvzf ssh.tar.gz

# !cp ssh-colab/* /root/.ssh && rm -rf ssh-colab
# !chmod 700 /root/.ssh

# !touch /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# Out:
# ssh-colab/
# ssh-colab/config
# ssh-colab/id_rsa_colab
# ssh-colab/id_rsa_colab.pub
# # github.com:22 SSH-2.0-babeld-76c80caa
# # github.com:22 SSH-2.0-babeld-76c80caa
# # github.com:22 SSH-2.0-babeld-76c80caa

# %%
# !ssh-agent /bin/bash
#ssh-add /root/.ssh/id_rsa_colab
#ssh-add -l
#exit
# Out:
# bash: cannot set terminal process group (123): Inappropriate ioctl for device
# bash: no job control in this shell
# root@f99aef2877a9:/content# ssh-add /root/.ssh/id_rsa_colab
# Identity added: /root/.ssh/id_rsa_colab (/root/.ssh/id_rsa_colab)
# root@f99aef2877a9:/content# ssh-add -l
# 2048 SHA256:SpU/DuMOwLsZmS9hdQfImWud0o5YhuYTkxLgNOtF1aA /root/.ssh/id_rsa_colab (RSA)
# root@f99aef2877a9:/content# exit
# exit

# %%
# !git config --global user.email 'rashmi.raviprasad@gmail.com'
# !git config --global user.name 'rashmi-raviprasad'

# %%
REPOSITORY = '/content/drive/My Drive/Springboard DS Course/REPOSITORY/springboard'

# %%
def save_to_git(commit_msg):
  os.chdir(REPOSITORY+'/faces_capstone2')
  os.environ['MSG'] = commit_msg
  # !git pull
  # !git add faces_decoder_reduced.ipynb push_to_git.ipynb decoder_25c.h5 train_log_25c.csv faces_decoder_reduced_2.ipynb decoder_50c.h5 train_log_50c.csv
  # !git commit -m $MSG
  # !git push

# %%
#N_TOT_EPOCHS = 141520
MINS_PER_COMMIT = 30
SECS_PER_COMMIT = 30 * 60

# %%
while True:
  message = 'training reduced model on 10k epochs w 50 components'
  message = message.replace(' ', '_')
  save_to_git(message)
  current_dt = datetime.now(pytz.timezone('US/Pacific'))
  print('time last pushed to git: %s' % current_dt)
  time.sleep(SECS_PER_COMMIT)
# Out:
# Already up to date.
# [master ad19a2a] training_reduced_model_on_10k_epochs_w_50_components
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite faces_capstone2/faces_decoder_reduced_2.ipynb (94%)
# Warning: Permanently added the RSA host key for IP address '140.82.114.3' to the list of known hosts.
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.29 KiB | 439.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    189fdbe..ad19a2a  master -> master
# time last pushed to git: 2020-04-18 02:43:45.842688-07:00
# Warning: Permanently added the RSA host key for IP address '140.82.112.3' to the list of known hosts.
# Already up to date.
# [master d455c83] training_reduced_model_on_10k_epochs_w_50_components
#  4 files changed, 10002 insertions(+), 2 deletions(-)
#  rewrite faces_capstone2/decoder_50c.h5 (80%)
#  rewrite faces_capstone2/faces_decoder_reduced_2.ipynb (94%)
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 1.56 MiB | 5.52 MiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    ad19a2a..d455c83  master -> master
# time last pushed to git: 2020-04-18 03:13:55.520705-07:00
# Already up to date.
# [master 0b6d5da] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Warning: Permanently added the RSA host key for IP address '140.82.113.3' to the list of known hosts.
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 589 bytes | 589.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    d455c83..0b6d5da  master -> master
# time last pushed to git: 2020-04-18 03:44:03.345276-07:00
# Warning: Permanently added the RSA host key for IP address '140.82.113.4' to the list of known hosts.
# Already up to date.
# [master 5f31327] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 586 bytes | 586.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    0b6d5da..5f31327  master -> master
# time last pushed to git: 2020-04-18 04:14:10.378237-07:00
# Already up to date.
# [master f17497e] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 506 bytes | 506.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    5f31327..f17497e  master -> master
# time last pushed to git: 2020-04-18 04:44:18.011999-07:00
# Already up to date.
# [master f477848] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 487 bytes | 487.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    f17497e..f477848  master -> master
# time last pushed to git: 2020-04-18 05:14:26.354124-07:00
# Already up to date.
# [master be01b08] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 465 bytes | 465.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    f477848..be01b08  master -> master
# time last pushed to git: 2020-04-18 05:44:33.462913-07:00
# Already up to date.
# [master f515eaf] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 466 bytes | 466.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    be01b08..f515eaf  master -> master
# time last pushed to git: 2020-04-18 06:14:40.753922-07:00
# Already up to date.
# [master a8610ce] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 477 bytes | 477.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    f515eaf..a8610ce  master -> master
# time last pushed to git: 2020-04-18 06:44:48.303227-07:00
# Already up to date.
# [master 6a42101] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 475 bytes | 475.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    a8610ce..6a42101  master -> master
# time last pushed to git: 2020-04-18 07:14:56.646006-07:00
# Already up to date.
# [master b6b891c] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 473 bytes | 473.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    6a42101..b6b891c  master -> master
# time last pushed to git: 2020-04-18 07:45:04.507885-07:00
# Already up to date.
# [master 1cb62b5] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 476 bytes | 476.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    b6b891c..1cb62b5  master -> master
# time last pushed to git: 2020-04-18 08:15:13.567004-07:00
# Already up to date.
# [master c5c5a8d] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 475 bytes | 237.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    1cb62b5..c5c5a8d  master -> master
# time last pushed to git: 2020-04-18 08:45:21.441862-07:00
# Already up to date.
# [master 8917527] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 453 bytes | 453.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    c5c5a8d..8917527  master -> master
# time last pushed to git: 2020-04-18 09:15:29.474923-07:00
# Already up to date.
# [master 2ff16b9] training_reduced_model_on_10k_epochs_w_50_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 472 bytes | 472.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    8917527..2ff16b9  master -> master
# time last pushed to git: 2020-04-18 09:45:37.342930-07:00

# %%
# !git reset --hard #1983091
# Out:
# HEAD is now at 1983091 training_reduced_model_on_50k_epochs

# %%
os.chdir(REPOSITORY)
# !git pull
# Out:
# Warning: Permanently added the RSA host key for IP address '140.82.113.3' to the list of known hosts.
# Already up to date.

# %%
os.chdir('/content/drive/My Drive/Springboard DS Course/CAPSTONE 2/IMAGES')
img_list = os.listdir('/content/drive/My Drive/Springboard DS Course/CAPSTONE 2/IMAGES/NEW_FINAL_PICS')
cat_dir = []
face_dir = []
for filename in tqdm(img_list):
  if '_' in filename:
    cat_dir.append(filename)
  else:
    face_dir.append(filename)
# Out:
# 100%|██████████| 56709/56709 [00:00<00:00, 2365161.04it/s]

# %%
import numpy as np

os.chdir('/content/drive/My Drive/Springboard DS Course/CAPSTONE 2/IMAGES/')
c = np.random.randint(len(cat_dir))
f = np.random.randint(len(face_dir))
os.environ['CAT'] = './NEW_FINAL_PICS/'+cat_dir[c]
os.environ['FACE'] = './NEW_FINAL_PICS/'+face_dir[f]
# !cp $CAT './REDUCED_DATASET'
# !cp $FACE './REDUCED_DATASET'
