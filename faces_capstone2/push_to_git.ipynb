# %%
import os
import time
import pytz
import pandas as pd
from tqdm import tqdm
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir('/content')
from google.colab import files
keys = files.upload()
# Out:
#      <input type="file" id="files-bc7ad087-12b3-4fbd-8ec5-07f19d89a9da" name="files[]" multiple disabled />
#      <output id="result-bc7ad087-12b3-4fbd-8ec5-07f19d89a9da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ssh.tar.gz to ssh.tar.gz

# %%
# !rm -rf /root/.ssh
# !mkdir /root/.ssh

# !tar xvzf ssh.tar.gz

# !cp ssh-colab/* /root/.ssh && rm -rf ssh-colab
# !chmod 700 /root/.ssh

# !touch /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# Out:
# ssh-colab/
# ssh-colab/config
# ssh-colab/id_rsa_colab
# ssh-colab/id_rsa_colab.pub
# # github.com:22 SSH-2.0-babeld-76c80caa
# # github.com:22 SSH-2.0-babeld-76c80caa
# # github.com:22 SSH-2.0-babeld-76c80caa

# %%
# !ssh-agent /bin/bash
#ssh-add /root/.ssh/id_rsa_colab
#ssh-add -l
#exit
# Out:
# bash: cannot set terminal process group (121): Inappropriate ioctl for device
# bash: no job control in this shell
# root@c0cb5ad79b87:/content# ssh-add /root/.ssh/id_rsa_colab
# Identity added: /root/.ssh/id_rsa_colab (/root/.ssh/id_rsa_colab)
# root@c0cb5ad79b87:/content# ssh-add -l
# 2048 SHA256:SpU/DuMOwLsZmS9hdQfImWud0o5YhuYTkxLgNOtF1aA /root/.ssh/id_rsa_colab (RSA)
# root@c0cb5ad79b87:/content# exit
# exit

# %%
# !git config --global user.email 'rashmi.raviprasad@gmail.com'
# !git config --global user.name 'rashmi-raviprasad'

# %%
REPOSITORY = '/content/drive/My Drive/Springboard DS Course/REPOSITORY/springboard'

# %%
def save_to_git(commit_msg):
  os.chdir(REPOSITORY+'/faces_capstone2')
  os.environ['MSG'] = commit_msg
  # !git pull
  # !git add faces_decoder_reduced.ipynb push_to_git.ipynb decoder_25c.h5 train_log_25c.csv faces_decoder_reduced_2.ipynb decoder_50c.h5 train_log_50c.csv
  # !git commit -m $MSG
  # !git push

# %%
#N_TOT_EPOCHS = 141520
MINS_PER_COMMIT = 30
SECS_PER_COMMIT = 30 * 60

# %%
while True:
  message = 'training reduced model on 10k epochs w 100 components'
  message = message.replace(' ', '_')
  save_to_git(message)
  current_dt = datetime.now(pytz.timezone('US/Pacific'))
  print('time last pushed to git: %s' % current_dt)
  time.sleep(SECS_PER_COMMIT)
# Out:
# ...
# Already up to date.
# [master 946932e] training_reduced_model_on_10k_epochs_w_100_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite faces_capstone2/push_to_git.ipynb (70%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 830 bytes | 830.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:rashmi-raviprasad/springboard.git
#    78209a3..946932e  master -> master
# time last pushed to git: 2020-04-20 11:59:36.037501-07:00
# ...
# Already up to date.
# [master c89bfac] training_reduced_model_on_10k_epochs_w_100_components
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite faces_capstone2/push_to_git.ipynb (65%)
# ...
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# ...

# %%
# !git reset --hard #1983091
# Out:
# HEAD is now at 1983091 training_reduced_model_on_50k_epochs

# %%
os.chdir(REPOSITORY)
# !git pull
# Out:
# ...
# Already up to date.

# %%
os.chdir('/content/drive/My Drive/Springboard DS Course/CAPSTONE 2/IMAGES')
img_list = os.listdir('/content/drive/My Drive/Springboard DS Course/CAPSTONE 2/IMAGES/NEW_FINAL_PICS')
cat_dir = []
face_dir = []
for filename in tqdm(img_list):
  if '_' in filename:
    cat_dir.append(filename)
  else:
    face_dir.append(filename)
# Out:
# 100%|██████████| 56709/56709 [00:00<00:00, 2365161.04it/s]

# %%
import numpy as np

os.chdir('/content/drive/My Drive/Springboard DS Course/CAPSTONE 2/IMAGES/')
c = np.random.randint(len(cat_dir))
f = np.random.randint(len(face_dir))
os.environ['CAT'] = './NEW_FINAL_PICS/'+cat_dir[c]
os.environ['FACE'] = './NEW_FINAL_PICS/'+face_dir[f]
# !cp $CAT './REDUCED_DATASET'
# !cp $FACE './REDUCED_DATASET'
